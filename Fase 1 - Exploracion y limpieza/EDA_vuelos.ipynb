# %%
#importamos las galerías necesarias
import numpy as np
import pandas as pd

#configuramos para ver todas las columnas
pd.set_option("display.max_columns", None)

# %%
#cargamos el dataset
df = pd.read_csv("/Users/lucianayelicich/Desktop/Adalab/bda-modulo-3-evaluacion-final-lucianayelicich/Data/Customer Flight Activity.csv")
df.head(2)
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
#
#    Dollar Cost Points Redeemed
# 0                            0
# 1                            0

# %%
#vemos cuántas filas tenemos
df.shape
# Out:
# (405624, 10)

# %%
#vemos las últimas filas del df
df.tail()
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 405619          999902  2018     12               0                        0
# 405620          999911  2018     12               0                        0
# 405621          999940  2018     12               3                        0
# 405622          999982  2018     12               0                        0
# 405623          999986  2018     12               0                        0
#
#         Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 405619              0         0                 0.0                0
# 405620              0         0                 0.0                0
# 405621              3      1233               123.0                0
# 405622              0         0                 0.0                0
# 405623              0         0                 0.0                0
#
#         Dollar Cost Points Redeemed
# 405619                            0
# ...

# %%
#vemos una muestra aleatoria del df
df.sample()
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 237158          129328  2018      3               0                        0
#
#         Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 237158              0         0                 0.0                0
#
#         Dollar Cost Points Redeemed
# 237158                            0

# %%
#obtenemos los nombres de todas las columnas
df.columns
# Out:
# Index(['Loyalty Number', 'Year', 'Month', 'Flights Booked',
#        'Flights with Companions', 'Total Flights', 'Distance',
#        'Points Accumulated', 'Points Redeemed', 'Dollar Cost Points Redeemed'],
#       dtype='object')

# %%
#obtenemos información de los datos contenidos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405624 entries, 0 to 405623
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Loyalty Number               405624 non-null  int64
#  1   Year                         405624 non-null  int64
#  2   Month                        405624 non-null  int64
#  3   Flights Booked               405624 non-null  int64
#  4   Flights with Companions      405624 non-null  int64
#  5   Total Flights                405624 non-null  int64
#  6   Distance                     405624 non-null  int64
#  7   Points Accumulated           405624 non-null  float64
#  8   Points Redeemed              405624 non-null  int64
#  9   Dollar Cost Points Redeemed  405624 non-null  int64
# dtypes: float64(1), int64(9)
# memory usage: 30.9 MB

# %%
#utilizamos .describe para obtener las principales estadísticas
df.describe().T
# Out:
#                                 count           mean            std       min  \
# Loyalty Number               405624.0  550037.873084  258935.286969  100018.0
# Year                         405624.0    2017.500000       0.500001    2017.0
# Month                        405624.0       6.500000       3.452057       1.0
# Flights Booked               405624.0       4.115052       5.225518       0.0
# Flights with Companions      405624.0       1.031805       2.076869       0.0
# Total Flights                405624.0       5.146858       6.521227       0.0
# Distance                     405624.0    1208.880059    1433.155320       0.0
# Points Accumulated           405624.0     123.692721     146.599831       0.0
# Points Redeemed              405624.0      30.696872     125.486049       0.0
# Dollar Cost Points Redeemed  405624.0       2.484503      10.150038       0.0
#
#                                    25%       50%        75%       max
# ...

# %%
#chequeamos que no existan nulos, como informa .info
df.isnull().sum()
# Out:
# Loyalty Number                 0
# Year                           0
# Month                          0
# Flights Booked                 0
# Flights with Companions        0
# Total Flights                  0
# Distance                       0
# Points Accumulated             0
# Points Redeemed                0
# Dollar Cost Points Redeemed    0
# dtype: int64

# %%
#chequeamos si existen duplicados
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 405619    False
# 405620    False
# 405621    False
# 405622    False
# 405623    False
# Length: 405624, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1864

# %%
#exploramos los valores únicos y la frequencia de éstos para cada columna, incluidos los nulos
for columna in df.columns:
    print(f"--- Frecuencias para la columna: {columna} ---")
    print(df[columna].value_counts(dropna=False))
    print("\n")
# Out:
# --- Frecuencias para la columna: Loyalty Number ---
# Loyalty Number
# 678205    72
# 833793    48
# 727091    48
# 700650    48
# 654433    48
#           ..
# 101515    24
# 101540    24
# 101544    24
# 101547    24
# 999891    24
# Name: count, Length: 16737, dtype: int64
#
#
# --- Frecuencias para la columna: Year ---
# Year
# 2017    202812
# 2018    202812
# Name: count, dtype: int64
#
#
# --- Frecuencias para la columna: Month ---
# Month
# 1     33802
# 9     33802
# 2     33802
# 3     33802
# 11    33802
# 4     33802
# 5     33802
# 7     33802
# 6     33802
# 8     33802
# 10    33802
# 12    33802
# Name: count, dtype: int64
#
#
# --- Frecuencias para la columna: Flights Booked ---
# Flights Booked
# 0     197992
# 3      18228
# 11     15705
# 5      15084
# 7      14561
# 8      14357
# 9      14164
# 6      13847
# 2      13641
# 10     13363
# 4      12821
# 1      12667
# 13     10782
# 12     10382
# 14      7057
# 15      6582
# 16      4354
# 17      3899
# ...

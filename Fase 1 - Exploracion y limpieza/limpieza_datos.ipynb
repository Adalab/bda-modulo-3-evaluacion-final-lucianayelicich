# %%
#importamos las galerías necesarias
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer 
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer 
from sklearn.impute import KNNImputer 


#configuramos para ver todas las columnas
pd.set_option("display.max_columns", None)

# %%
#cargamos el primer dataset, no usamos reset index para que la columna Loyalty Number se comporte como tal
df_vuelos = pd.read_csv("/Users/lucianayelicich/Desktop/Adalab/bda-modulo-3-evaluacion-final-lucianayelicich/Data/Customer Flight Activity.csv")
df_vuelos.head()
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    Dollar Cost Points Redeemed
# 0                            0
# 1                            0
# 2                            0
# ...

# %%
#cargamos el segundo dataset, no usamos reset index para que la columna Loyalty Number se comporte como tal
df_fidelidad = pd.read_csv("/Users/lucianayelicich/Desktop/Adalab/bda-modulo-3-evaluacion-final-lucianayelicich/Data/Customer Loyalty History.csv")
df_fidelidad.head()
# Out:
#    Loyalty Number Country          Province       City Postal Code  Gender  \
# 0          480934  Canada           Ontario    Toronto     M2Z 4K1  Female
# 1          549612  Canada           Alberta   Edmonton     T3G 6Y6    Male
# 2          429460  Canada  British Columbia  Vancouver     V6E 3D9    Male
# 3          608370  Canada           Ontario    Toronto     P1W 1K4    Male
# 4          530508  Canada            Quebec       Hull     J8Y 3Z5    Male
#
#   Education    Salary Marital Status Loyalty Card      CLV Enrollment Type  \
# 0  Bachelor   83236.0        Married         Star  3839.14        Standard
# 1   College       NaN       Divorced         Star  3839.61        Standard
# 2   College       NaN         Single         Star  3839.75        Standard
# 3   College       NaN         Single         Star  3839.75        Standard
# 4  Bachelor  103495.0        Married         Star  3842.79        Standard
#
# ...

# %%
#verificamos la cantidad de filas y columnas de cada dataframe
display(df_fidelidad.shape)
display(df_vuelos.shape)
# Out:
# (16737, 16)
# (405624, 10)

# %%
#verificamos los nombres de las columnas para identificar las claves de unión
display(df_fidelidad.columns.to_list())
display(df_vuelos.columns.to_list())
# Out:
# ['Loyalty Number',
#  'Country',
#  'Province',
#  'City',
#  'Postal Code',
#  'Gender',
#  'Education',
#  'Salary',
#  'Marital Status',
#  'Loyalty Card',
#  'CLV',
#  'Enrollment Type',
#  'Enrollment Year',
#  'Enrollment Month',
#  'Cancellation Year',
#  'Cancellation Month']
# ['Loyalty Number',
#  'Year',
#  'Month',
#  'Flights Booked',
#  'Flights with Companions',
#  'Total Flights',
#  'Distance',
#  'Points Accumulated',
#  'Points Redeemed',
#  'Dollar Cost Points Redeemed']

# %%
#chequeamos los duplicados en cada df
df_fidelidad.duplicated().sum()
# Out:
# 0

# %%
df_vuelos.duplicated().sum()
# Out:
# 1864

# %%
#unimos los dataframes con merge, para que la unión se haga por la columna Loyalty Number y se mantenga la integridad de datos

df_aviacion = df_vuelos.merge(right=df_fidelidad, how="left", left_on="Loyalty Number", right_on="Loyalty Number")
df_aviacion.head()
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    Dollar Cost Points Redeemed Country          Province          City  \
# 0                            0  Canada           Alberta      Edmonton
# ...

# %%
#chequeamos que esten todas las filas
df_aviacion.shape
# Out:
# (405624, 25)

# %%
#tomamos una muestra aleatoria del dataframe
df_aviacion.sample(10)
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 66199           924878  2017      4               0                        0
# 75164           502212  2017      5               0                        0
# 200924          898698  2017     12               5                        1
# 162163          634418  2017     10              11                        4
# 26929           633140  2017      2               6                        3
# 86757           219984  2017      6               0                        0
# 265077          714757  2018      4               0                        0
# 219441          984429  2018      1               8                        1
# 65843           905806  2017      4              12                        1
# 384963          797120  2018     11               5                        0
#
#         Total Flights  Distance  Points Accumulated  Points Redeemed  \
# ...

# %%
#chequeamos la cantidad de nulos
df_aviacion.duplicated().sum()
# Out:
# 1864

# %%
#aplicamos una máscara para garantizar que no eliminemos duplicados sólo basados en el loyalty number, que puede ser engañoso
mascara = df_aviacion.duplicated(keep=False)
df_aviacion[mascara].sort_values(["Loyalty Number", "Month"])
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 41              101902  2017      1               0                        0
# 42              101902  2017      1               0                        0
# 16942           101902  2017      2               0                        0
# 16943           101902  2017      2               0                        0
# 33843           101902  2017      3               0                        0
# ...                ...   ...    ...             ...                      ...
# 304081          992168  2018      6               0                        0
# 151971          992168  2017      9               0                        0
# 151972          992168  2017      9               0                        0
# 354783          992168  2018      9               0                        0
# 354784          992168  2018      9               0                        0
#
# ...

# %%
#eliminamos duplicados
df_aviacion = df_aviacion.drop_duplicates()

# %%
#chequeamos que no existan más duplicados
df_aviacion.duplicated().sum()
# Out:
# 0

# %%
#corronoramos la extensión actual del df
df_aviacion.shape
# Out:
# (403760, 25)

# %%
#guardamos una copia del dataframe en una nueva variable para efectuar la limpieza
df_final = df_aviacion.copy()
df_final.head()
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    Dollar Cost Points Redeemed Country          Province          City  \
# 0                            0  Canada           Alberta      Edmonton
# ...

# %%
#revisamos valores nulos absolutos
df_final.isnull().sum()
# Out:
# Loyalty Number                      0
# Year                                0
# Month                               0
# Flights Booked                      0
# Flights with Companions             0
# Total Flights                       0
# Distance                            0
# Points Accumulated                  0
# Points Redeemed                     0
# Dollar Cost Points Redeemed         0
# Country                             0
# Province                            0
# City                                0
# Postal Code                         0
# Gender                              0
# Education                           0
# Salary                         102260
# Marital Status                      0
# Loyalty Card                        0
# CLV                                 0
# Enrollment Type                     0
# Enrollment Year                     0
# Enrollment Month                    0
# Cancellation Year              354110
# Cancellation Month             354110
# ...

# %%
#dividimos la suma de valores nulos entre el número de filas del df y multiplicamos por 100 para sacar el porcentaje o frequencia relativa de nulos y los ordenamos
round((df_final.isnull().sum() / df_final.shape[0]) * 100,2).sort_values(ascending=False)
# Out:
# Cancellation Month             87.70
# Cancellation Year              87.70
# Salary                         25.33
# Year                            0.00
# Flights with Companions         0.00
# Total Flights                   0.00
# Month                           0.00
# Flights Booked                  0.00
# Loyalty Number                  0.00
# Points Redeemed                 0.00
# Points Accumulated              0.00
# Distance                        0.00
# Dollar Cost Points Redeemed     0.00
# City                            0.00
# Postal Code                     0.00
# Province                        0.00
# Country                         0.00
# Education                       0.00
# Gender                          0.00
# Marital Status                  0.00
# Loyalty Card                    0.00
# Enrollment Type                 0.00
# CLV                             0.00
# Enrollment Month                0.00
# Enrollment Year                 0.00
# dtype: float64

# %%
#debido a que el mes y el año de cancelación tienen muchos datos NaN, pero que en el resumen brindado se aclara que los datos se
#brindan solo en caso de corresponder, interpretamos que dichas membresías están vigentes y no han sido canceladas
#por lo que los mismos no serán imputados

# %%
#obtenemos las principales estadísticas del df, para chequear datos atípicos o nulos
df_final.describe().T
# Out:
#                                 count           mean            std  \
# Loyalty Number               403760.0  549875.383713  258961.514684
# Year                         403760.0    2017.500352       0.500000
# Month                        403760.0       6.501335       3.451982
# Flights Booked               403760.0       4.134050       5.230064
# Flights with Companions      403760.0       1.036569       2.080472
# Total Flights                403760.0       5.170619       6.526858
# Distance                     403760.0    1214.460979    1434.098521
# Points Accumulated           403760.0     124.263761     146.696179
# Points Redeemed              403760.0      30.838587     125.758002
# Dollar Cost Points Redeemed  403760.0       2.495973      10.172033
# Salary                       301500.0   79258.576285   34983.929798
# CLV                          403760.0    7990.864857    6863.317160
# Enrollment Year              403760.0    2015.250716       1.979427
# ...

# %%
#observamos que la columna Salary tiene valores negativos, lo cual es imposible y se trata de un dato incoherente
#chequeamos esa columna en particular para cerciorarnos que se trata de un error en la recolección del dato
df_final["Salary"].agg(["mean", "median", "std", "var", "min", "max"])
# Out:
# mean      7.925858e+04
# median    7.347900e+04
# std       3.498393e+04
# var       1.223875e+09
# min      -5.848600e+04
# max       4.072280e+05
# Name: Salary, dtype: float64

# %%
#debemos quitar el guión de la columna Salary, para lo cual primero debemos transformarla a tipo str, para aplicar el replace
df_final['Salary'] = df_final['Salary'].astype(str)

#reemplazamos el guion "-" por una cadena vacía, lo que remueve el guion de cualquier valor en la columna.
df_final['Salary'] = df_final['Salary'].str.replace('-', '', regex=False)

#convertimos la columna de vuelta a tipo numérico, y le indicamos que lo que no pueda corregir lo transforme a NaN
df_final['Salary'] = pd.to_numeric(df_final['Salary'], errors='coerce')

print("La columna 'Salary' ha sido limpiada y ahora tiene un formato numérico.")
print(df_final['Salary'].head())
# Out:
# La columna 'Salary' ha sido limpiada y ahora tiene un formato numérico.
# 0    92552.0
# 1        NaN
# 2        NaN
# 3    63253.0
# 4    91163.0
# Name: Salary, dtype: float64

# %%
#decidimos imputar los valores nulos de la columna Salary usando IterativeImputer porque es una estrategia de imputación avanzada 
#que preserva las relaciones y dependencias entre las variables. A diferencia de métodos simples como la media o la mediana, 
#IterativeImputer considera el valor de otras columnas para hacer una estimación más precisa
print("\n--- Imputación con métodos avanzados (IterativeImputer) ---")
# Haremos una copia del DataFrame para aplicar ambos métodos y comparar.
df_final_copia = df_final.copy()

#definimos las columnas a usar para la imputación, que son columnas numéricas relacionadas con el salario
columnas_para_imputar = ["Salary", "CLV", "Flights Booked", "Points Accumulated"] 

#ajustamos el imputador con todas las columnas seleccionadas
imputer_iterative = IterativeImputer(max_iter=20, random_state=42)
imputado_iterative = imputer_iterative.fit_transform(df_final_copia[columnas_para_imputar])

# La primera columna del resultado imputado es la de "Salary"
df_final_copia["Salary_iterative"] = imputado_iterative[:, 0]
print(f"Después del 'IterativeImputer' tenemos: \n{df_final_copia[['Salary_iterative']].isnull().sum()} nulos")
# Out:
# --- Imputación con métodos avanzados (IterativeImputer) ---
# Después del 'IterativeImputer' tenemos:
# Salary_iterative    0
# dtype: int64 nulos

# %%
#chequemos cómo queda el df
df_final_copia.head()
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    Dollar Cost Points Redeemed Country          Province          City  \
# 0                            0  Canada           Alberta      Edmonton
# ...

# %%
#comparamos los resultados de IterativeImputer y la columna original
print("\n--- Comparando estadísticos de la columna original y la imputada ---")
# Compararemos los estadísticos (media, mediana, etc.) antes y después de la imputación.
# Nos quedaremos con el método que menos modifique los estadísticos.
df_final_copia.describe()[["Salary", "Salary_iterative"]]
# Out:
# --- Comparando estadísticos de la columna original y la imputada ---
#               Salary  Salary_iterative
# count  301500.000000     403760.000000
# mean    79371.732902      79387.173990
# std     34726.433958      30010.791123
# min      9081.000000       9081.000000
# 25%     59262.000000      63901.000000
# 50%     73479.000000      79121.337688
# 75%     88606.000000      82940.000000
# max    407228.000000     407228.000000

# %%
#eliminamos la columna 'Salary' original (la que tiene NaN)
df_final_copia = df_final_copia.drop(columns=['Salary'])

#renombramos la columna 'Salary_iterative' a 'Salary'
df_final_copia.rename(columns={"Salary_iterative": "Salary"}, inplace=True)

#reordenamos las columnas
columnas = df_final_copia.columns.tolist()
columnas.remove('Salary')

#creamos un indice con los titulos de las columnas
posicion_educacion = columnas.index('Education')

#le indicamos al df que debe insertar la columna salary nuevamente en su lugar original, despues de education
columnas.insert(posicion_educacion + 1, 'Salary')

#asignamos el nuevo orden al DataFrame
df_final_copia = df_final_copia[columnas]

print("Columnas después de la reorganización:")
print(df_final_copia.columns.tolist())
# Out:
# Columnas después de la reorganización:
# ['Loyalty Number', 'Year', 'Month', 'Flights Booked', 'Flights with Companions', 'Total Flights', 'Distance', 'Points Accumulated', 'Points Redeemed', 'Dollar Cost Points Redeemed', 'Country', 'Province', 'City', 'Postal Code', 'Gender', 'Education', 'Salary', 'Marital Status', 'Loyalty Card', 'CLV', 'Enrollment Type', 'Enrollment Year', 'Enrollment Month', 'Cancellation Year', 'Cancellation Month']

# %%
#chequeamos el df
df_final_copia.head()
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    Dollar Cost Points Redeemed Country          Province          City  \
# 0                            0  Canada           Alberta      Edmonton
# ...

# %%
#del análisis EDA que realizamos, nos percatamos que el mes y año son valores de tipo numérico y no de fecha, por lo que debemos corregirlo
#para ello primero hay que unir ambbos datos en una sola columna
#creamos la columna 'Date' y la convertimos a tipo datetime
df_final_copia['Date'] = pd.to_datetime(df_final_copia['Month'].astype(str) + '-' + df_final_copia['Year'].astype(str))

#indicamos que la nueva columna se inserte en el lugar original del df
df_final_copia.insert(loc=1, column='Date', value=df_final_copia.pop('Date'))

#verificamos que la conversión haya funcionado
print("Tipo de dato de la columna 'Date':", df_final_copia['Date'].dtype)

df_final_copia.head()
# Out:
# Tipo de dato de la columna 'Date': datetime64[ns]
#    Loyalty Number       Date  Year  Month  Flights Booked  \
# 0          100018 2017-01-01  2017      1               3
# 1          100102 2017-01-01  2017      1              10
# 2          100140 2017-01-01  2017      1               6
# 3          100214 2017-01-01  2017      1               0
# 4          100272 2017-01-01  2017      1               0
#
#    Flights with Companions  Total Flights  Distance  Points Accumulated  \
# 0                        0              3      1521               152.0
# 1                        4             14      2030               203.0
# 2                        0              6      1200               120.0
# 3                        0              0         0                 0.0
# 4                        0              0         0                 0.0
#
#    Points Redeemed  Dollar Cost Points Redeemed Country          Province  \
# ...

# %%
#eliminamos las columnas year y month por ser redundantes e innecesarias
df_final_copia.drop(columns=["Year", "Month"], axis=1, inplace=True)

# %%
#chequeamos el df
df_final_copia.head()
# Out:
#    Loyalty Number       Date  Flights Booked  Flights with Companions  \
# 0          100018 2017-01-01               3                        0
# 1          100102 2017-01-01              10                        4
# 2          100140 2017-01-01               6                        0
# 3          100214 2017-01-01               0                        0
# 4          100272 2017-01-01               0                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    Dollar Cost Points Redeemed Country          Province          City  \
# 0                            0  Canada           Alberta      Edmonton
# ...

# %%
#guardamos nuestro df depurado en un csv para pasar a la fase de visualización
df_final_copia.to_csv("archivo_aviacion_final.csv")

# %%
#importamos las galerías necesarias
import numpy as np
import pandas as pd

#configuramos para ver todas las columnas
pd.set_option("display.max_columns", None)

# %%
#cargamos el dataset
df_evaluacion = pd.read_csv("/Users/lucianayelicich/Desktop/Adalab/bda-modulo-3-evaluacion-final-lucianayelicich/Data/archivo_aviacion_final.csv")
df_evaluacion.head()
# Out:
#    Loyalty Number        Date  Flights Booked  Flights with Companions  \
# 0          100018  2017-01-01               3                        0
# 1          100102  2017-01-01              10                        4
# 2          100140  2017-01-01               6                        0
# 3          100214  2017-01-01               0                        0
# 4          100272  2017-01-01               0                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    Dollar Cost Points Redeemed Country          Province          City  \
# 0                            0  Canada           Alberta      Edmonton
# ...

# %%
#obtenemos la media de todas las columnas numéricas agrupadas por educación
df_evaluacion.groupby("Education").mean(numeric_only=True).T #hacemos transpose para verlas con claridad
# Out:
# Education                         Bachelor        College         Doctor  \
# Loyalty Number               548114.325134  549280.619010  570327.226834
# Flights Booked                    4.110288       4.169744       4.175512
# Flights with Companions           1.030713       1.048582       1.026056
# Total Flights                     5.141000       5.218326       5.201568
# Distance                       1208.446626    1220.214121    1231.799278
# Points Accumulated              123.733841     124.729674     125.939187
# Points Redeemed                  30.531083      31.422589      31.814957
# Dollar Cost Points Redeemed       2.471027       2.543311       2.574530
# Salary                        72599.080913   79432.699982  178403.675202
# CLV                            8211.231866    7584.627706    7815.738556
# Enrollment Year                2015.261016    2015.266781    2015.077266
# Enrollment Month                  6.647032       6.668072       6.907337
# ...

# %%
#filtramos el conjunto de datos para incluir únicamente las columnas relevantes: 'Flights Booked' y 'Education', y calculamos las estadísticas descriptivas básicas
educacion_reservas = df_evaluacion.groupby("Education")["Flights Booked"].agg(["mean", "median", "std", "var", "min", "max"])
educacion_reservas
# Out:
#                           mean  median       std        var  min  max
# Education
# Bachelor              4.091093     1.0  5.216995  27.217041    0   21
# College               4.153012     1.0  5.242136  27.479991    0   21
# Doctor                4.146281     1.0  5.250093  27.563479    0   21
# High School or Below  4.155777     1.0  5.234551  27.400523    0   21
# Master                4.184014     1.0  5.210294  27.147166    0   21
